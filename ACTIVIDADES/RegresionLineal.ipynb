# %%
"""
Nombre:Raymundo Bautista Reyes
Actividad 3:Solucion de problemas
Matricula:2082326
Hora:N1
"""
codigo = "Esta es mi presentacion para la actividad 3 la cual es entrenar a un modelo de regresion lineal con python"
print(codigo)
# Out:
# Esta es mi presentacion para la actividad 3 la cual es entrenar a un modelo de regresion lineal con python

# %%
# Cargaremos nuestras Librerías a utilizar
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Cargar conjunto de datos
np.random.seed(0)
horas_estudio = np.random.rand(100, 1) * 10
calificaciones = 2 * horas_estudio + np.random.randn(100, 1) * 2

# %%
# Preparar conjunto  de datos // Dividiremos los datos en conjuntos de entrenamiento y prueba para poder apreciarlo mejor//
train_data, test_data, train_labels, test_labels = train_test_split(horas_estudio, calificaciones, test_size=0.2, random_state=42)

# %%
# Seleccionar el modelo a entrenar: Regresión lineal
model = LinearRegression()
model.fit(train_data, train_labels)
# Out:
# LinearRegression()

# %%
# Predicciones con el modelo entrenado.
predictions = model.predict(test_data)
mse = mean_squared_error(test_labels, predictions)
print(f"Error cuadrático medio: {mse:.2f}")
# Out:
# Error cuadrático medio: 3.67

# %%
# Gráfica final con el modelo entrenado
plt.scatter(test_data, test_labels, label="Datos reales")
plt.plot(test_data, predictions, color='blue', label="Predicciones")
plt.xlabel("Horas de estudio")
plt.ylabel("Calificaciones")
plt.legend()
plt.show()
